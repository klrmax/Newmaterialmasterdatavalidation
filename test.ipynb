# %%
import pandas as pd
import os
import re
import openpyxl
from typing import List, Any, Callable, Set, Tuple
from decompa import DECompa # The de-compounding library not able to download (Bosch Firewall)

# %%
SOURCE_FILENAME = 'TEST_Data_for_REGEX.xlsx'
SOURCE_COLUMN_NAME = 'Typkurzbezeichnung'
CONDITION_COLUMN = 'MArt'
TARGET_FLAG_COLUMN = 'B' # Will contain 1 or ""
TARGET_REASON_COLUMN = 'lsg'    # Will contain the detailed reason

# Conditional Values
CONDITION_VALUES = ['BREX', 'KAUF'] # Check if MArt is one of these

# Resource File Names
STOPWORDS_FILENAME = 'german_stopwords.txt'
DICTIONARY_FILENAME = 'german_dictionary.txt'

# Validation Parameters
MIN_TOKEN_LENGTH = 3

# %%
# ==============================================================================
# 1. SETUP AND RESOURCE LOADING FUNCTIONS
# ==============================================================================

def load_text_file_to_set(filename: str) -> Set[str]:
    """Loads a .txt file (one item per line) into a lowercase set for fast lookups."""
    try:
        with open(filename, 'r', encoding='utf-8') as f:
            # Use a set for O(1) average time complexity checks (very fast)
            # .strip() removes whitespace, .lower() ensures case-insensitivity
            return {line.strip().lower() for line in f if line.strip()}
    except FileNotFoundError:
        print(f"⚠️ WARNING: Resource file '{filename}' not found. This check will be skipped.")
        return set()

def load_data(file_path: str) -> pd.DataFrame:
    """Loads data from an Excel file into a pandas DataFrame."""
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"The file was not found at: {file_path}")
    print(f"Loading data from '{os.path.basename(file_path)}'...")
    return pd.read_excel(file_path)

def save_data_to_excel(file_path: str, results_df: pd.DataFrame):
    """
    Opens an Excel workbook and updates multiple columns with new data,
    preserving all existing formatting.
    """
    print(f"Opening workbook to write results...")
    try:
        workbook = openpyxl.load_workbook(file_path)
        sheet = workbook.active
    except FileNotFoundError:
        raise FileNotFoundError(f"Failed to open workbook. Not found at: {file_path}")

    # Create a mapping from column name to its numerical index
    header = {cell.value: cell.column for cell in sheet[1]}
    
    # Update each column specified in the results DataFrame
    for col_name in results_df.columns:
        if col_name not in header:
            print(f"⚠️ WARNING: Target column '{col_name}' not found in Excel. It will be skipped.")
            continue
        
        target_col_num = header[col_name]
        print(f"Writing data to column '{col_name}'...")
        for index, value in results_df[col_name].items():
            sheet.cell(row=index + 2, column=target_col_num, value=value)
            
    try:
        workbook.save(file_path)
    except PermissionError:
        raise PermissionError(f"Could not save. Is the file '{os.path.basename(file_path)}' open in Excel?")

# %%
class TextValidator:
    """A class to encapsulate the entire validation logic and its resources."""
    
    def __init__(self, stopwords_path: str, dictionary_path: str):
        print("Initializing validator and loading resources...")
        # Load resources into memory once
        self.stopwords = load_text_file_to_set(stopwords_path)
        self.dictionary = load_text_file_to_set(dictionary_path)
        self.decompounder = DECompa()

    def _stage1_invalid_char_check(self, text: str) -> Tuple[bool, str]:
        """Stage 1: Checks for forbidden characters."""
        pattern = r"[^A-Z0-9*.,\"%/ :;=<>()–-&Ä´`_Ø+ \r\n-]"
        if re.search(pattern, text, re.IGNORECASE):
            return True, "Contains Invalid Characters"
        return False, ""

    def _stage2_german_language_analysis(self, text: str) -> Tuple[bool, str]:
        """Stage 2: Tokenizes text and runs checks on each token."""
        # Step A: Extract tokens of 3 or more letters
        tokens = re.findall(r'[A-Za-z]{' + str(MIN_TOKEN_LENGTH) + r',}', text)
        
        for token in tokens:
            token_lower = token.lower()
            
            # Check 1: Stop words
            if token_lower in self.stopwords:
                return True, f"Contains Stop Word: {token}"
            
            # Check 2: Direct dictionary match
            if token_lower in self.dictionary:
                return True, f"Contains Dictionary Word: {token}"
                
            # Check 3: Morphological check (only if not a direct match)
            parts = self.decompounder.split(token)
            # The word was successfully de-compounded if it has more than 1 part
            # and all of its parts are known dictionary words.
            if len(parts) > 1 and all(part.lower() in self.dictionary for part in parts):
                return True, f"Contains Compound Word: {token}"
        
        return False, ""

    def validate(self, text: Any) -> Tuple[int, str]:
        """
        Runs the full validation pipeline on a single piece of text.
        Returns a tuple: (flag, reason). e.g., (1, "Contains Stop Word: FUER")
        """
        if not isinstance(text, str) or not text.strip():
            return "", "" # Not an error, just empty

        # Run Stage 1
        is_error, reason = self._stage1_invalid_char_check(text)
        if is_error:
            return 1, reason

        # Run Stage 2
        is_error, reason = self._stage2_german_language_analysis(text)
        if is_error:
            return 1, reason

        # If all checks pass
        return "", ""

# %%
def main():
    """Main function to orchestrate the entire data processing workflow."""
    process_name = "Advanced Material Master Data Validation"
    print(f"--- Starting: {process_name} ---")
    try:
        # Get absolute paths for resource files
        script_dir = os.path.dirname(__file__)
        excel_file_path = os.path.join(script_dir, SOURCE_FILENAME)
        stopwords_path = os.path.join(script_dir, STOPWORDS_FILENAME)
        dictionary_path = os.path.join(script_dir, DICTIONARY_FILENAME)
        
        # Step 1: Load data and initialize validator
        df = load_data(excel_file_path)
        validator = TextValidator(stopwords_path, dictionary_path)
        
        # Check that all necessary columns exist
        required_cols = [SOURCE_COLUMN_NAME, CONDITION_COLUMN]
        if not all(col in df.columns for col in required_cols):
            raise ValueError(f"Required columns ({required_cols}) not found.")

        # Step 2: Apply the validation logic row-by-row
        print("Running conditional validation pipeline...")
        
        def apply_full_validation(row: pd.Series) -> pd.Series:
            """Applies validation logic to a single row and returns results for both target columns."""
            flag, reason = "", "" # Default values are "no error"
            
            # Conditional check: only run validation if MArt is one of the specified values
            if row[CONDITION_COLUMN] in CONDITION_VALUES:
                source_text = row[SOURCE_COLUMN_NAME]
                flag, reason = validator.validate(source_text)
            
            return pd.Series([flag, reason], index=[TARGET_FLAG_COLUMN, TARGET_REASON_COLUMN])

        # df.apply returns a new DataFrame with our two new columns
        results_df = df.apply(apply_full_validation, axis=1)

        # Step 3: Save the results back to the original Excel file
        save_data_to_excel(excel_file_path, results_df)

        print("\n" + "="*50)
        print("✅ SUCCESS: Workflow completed without errors.")
        print("="*50)

    except (FileNotFoundError, ValueError, PermissionError) as e:
        print(f"\n❌ ERROR: The script failed. Reason: {e}")
    except Exception as e:
        print(f"\n❌ An unexpected error occurred: {e}")

# ==============================================================================
# 4. SCRIPT ENTRY POINT
# ==============================================================================

if __name__ == "__main__":
    main()
# Out:
# --- Starting: Advanced Material Master Data Validation ---
#
# ❌ An unexpected error occurred: name '__file__' is not defined

# %%
german_words = load_text_file_to_set("german_words.txt")
french_words = load_text_file_to_set("")
stop_words = load_text_file_to_set("german_stopwords.txt")
english_words = load_text_file_to_set("english_words.txt")

Test = load_text_file_to_set("Typkurzbezeichnung TEST V1.txt")

def stage2_word_analysis(text: str) -> Tuple[bool, str]:
        """Stage 2: Tokenizes text and runs checks on each token."""

        print(text)
        # Step A: Extract tokens of 3 or more letters
        tokens = re.findall(r'[A-Za-z]{' + str(MIN_TOKEN_LENGTH) + r',}', text)
        
        for token in tokens:
            token_lower = token.lower()
            
            # Check 1: Stop words
            if token_lower in stop_words:
                return True, f"Contains Stop Word: {token}"
            
            #Check 2: English Words
            if token_lower in english_words:
                 continue
            
            # Check 2: Direct dictionary match
            if token_lower in german_words:
                return True, f"Contains Dictionary Word: {token}"
            
            #check 3: Compound word check 
            for word in german_words:
                 if len(word)>=4 and word in token_lower:
                      return True, f"Contains compound partial word: {word} for Token: {token}"
        
        return False, ""

for typcode in Test: 
    print(stage2_word_analysis(typcode))
# Out:
# 0500x0500x0055/0384 s1--a teil1  d900398
# (True, 'Contains Stop Word: teil')
# druckstueck r902774821
# (True, 'Contains compound partial word: rucks for Token: druckstueck ')
# grund,wsm
# (True, 'Contains Dictionary Word: grund')
# vorstufe unlackiert fuer r917016850
# (True, 'Contains Stop Word: vorstufe')
# agev2-26970-aa-101 filteranbaublock
# (True, 'Contains compound partial word: block for Token: filteranbaublock ')
# 20-20 vhm i-smart schrupp
# (True, 'Contains compound partial word: rupp for Token: schrupp ')
# cz112842 for 3032376-400
# (True, 'Contains Stop Word: for')
# vorstufe unlackiert fuer r917016819
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016870
# (True, 'Contains Stop Word: vorstufe')
# stempel 75.0.0955 stl.
# (True, 'Contains Stop Word: stempel')
# vorstufe unlackiert fuer r917016811
# (True, 'Contains Stop Word: vorstufe')
# druckstueck r902775048
# (True, 'Contains compound partial word: rucks for Token: druckstueck ')
# speicher,2-fach
# (True, 'Contains Stop Word: speicher')
# abhag-nutmutter-spalt-verstellen/2al
# (True, 'Contains compound partial word: mutter for Token: nutmutter ')
# typkurzbezeichnung test v1
# (True, 'Contains compound partial word: zeichnung for Token: typkurzbezeichnung ')
# buchse  60,0 / 120,0 x 150,0 stuetzweite
# (True, 'Contains Dictionary Word: buchse')
# druckstueck r902774619
# (True, 'Contains compound partial word: rucks for Token: druckstueck ')
# 013958 cr probe
# (True, 'Contains Stop Word: probe')
# sealing cover w1b-0-0-15.5-o-o
# (False, '')
# ng6 adaptor block right side(ng6.18)
# (False, '')
# sb34-ehs scheibe (iam)
# (True, 'Contains Stop Word: scheibe')
# zu 0608090742
# (False, '')
# vorstufe unlackiert fuer r917016808
# (True, 'Contains Stop Word: vorstufe')
# bedienpult 800x600x210 amtrion 40111-01
# (True, 'Contains compound partial word: pult for Token: bedienpult ')
# ng6 adaptor block left side(ng6.17)
# (False, '')
# abmaxin special_pump-motor stnation.
# (True, 'Contains compound partial word: maxi for Token: abmaxin ')
# abg-032,deckelpl,bev32,wv/rv,-004
# (True, 'Contains compound partial word: decke for Token: deckelpl ')
# vorstufe unlackiert fuer r917016812
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016820
# (True, 'Contains Stop Word: vorstufe')
# abcoc/057-w422/motor speicher
# (True, 'Contains Stop Word: speicher')
# oberkolben,2xbev50
# (True, 'Contains compound partial word: kolben for Token: oberkolben ')
# agev1-49820aa liste1 *alu
# (True, 'Contains Stop Word: liste')
# vorstufe unlackiert fuer r917016813
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016867
# (True, 'Contains Stop Word: vorstufe')
# b3, a24-hinten 73122.
# (True, 'Contains Stop Word: hinten')
# sy-eto-hci-pumpenprüfstand-rng
# (True, 'Contains compound partial word: pumpe for Token: pumpenpr ')
# vorstufe unlackiert fuer r917016821
# (True, 'Contains Stop Word: vorstufe')
# messvorrichtung 4 40-1000  80.0.0889
# (True, 'Contains compound partial word: vorrichtung for Token: messvorrichtung ')
# w rings flu:kennz+ver m
# (True, 'Contains compound partial word: kenn for Token: kennz ')
# druckstueck  r902774618
# (True, 'Contains compound partial word: rucks for Token: druckstueck ')
# vorstufe unlackiert fuer r917016823
# (True, 'Contains Stop Word: vorstufe')
# xhsr 06-ersatz fuer r901241534
# (True, 'Contains Stop Word: ersatz')
# a10-hochdruck-tankdruck
# (True, 'Contains Dictionary Word: hochdruck')
# vorstufe unlackiert fuer r917016869
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016832
# (True, 'Contains Stop Word: vorstufe')
# spannschraube r902776163
# (True, 'Contains Dictionary Word: spannschraube')
# soldered tube      cp-10 sr l=625 ss316l
# (False, '')
# sealing cover  casting azpw
# (False, '')
# vorstufe unlackiert fuer r917016824
# (True, 'Contains Stop Word: vorstufe')
# g1/2" bsp for od.15 cartridge
# (True, 'Contains Stop Word: for')
# hd-zpfp-001401-a-1/bedienpult wandhalter
# (True, 'Contains compound partial word: pult for Token: bedienpult ')
# soufflet 4the5 drt  jcb  inj
# (False, '')
# vorstufe unlackiert fuer r917016831
# (True, 'Contains Stop Word: vorstufe')
# cz112841 for 3032376-300
# (True, 'Contains Stop Word: for')
# abmaxin special_re-circulating unit
# (True, 'Contains compound partial word: maxi for Token: abmaxin ')
# verlagerung 3d printer
# (True, 'Contains Stop Word: verlagerung')
# vorstufe unlackiert fuer r917016817
# (True, 'Contains Stop Word: vorstufe')
# abmaxin special_return line filter unit
# (True, 'Contains compound partial word: maxi for Token: abmaxin ')
# vorstufe unlackiert fuer r917016810
# (True, 'Contains Stop Word: vorstufe')
# zl 2", pn40, 1.4408/ptfe, 2-teilig
# (True, 'Contains compound partial word: eilig for Token: teilig ')
# 2wfc vorst.
# (True, 'Contains compound partial word: vors for Token: vorst ')
# xxx
# (False, '')
# stoessel r909452755
# (True, 'Contains compound partial word: esse for Token: stoessel ')
# 50/32 mf for rb16112256
# (True, 'Contains Stop Word: for')
# cz112786 for 3050717
# (True, 'Contains Stop Word: for')
# vt-bac860-1-2x/magazineinbau-konf
# (True, 'Contains compound partial word: einbau for Token: magazineinbau ')
# pfp019-p085-pneum. proportionalventil
# (True, 'Contains compound partial word: port for Token: proportionalventil ')
# for-vsd-150-m16x1,5-hex21
# (True, 'Contains Stop Word: for')
# trennmaschine      inv 9638
# (True, 'Contains compound partial word: maschine for Token: trennmaschine ')
# rahmen sy 2168x 775x2200/st/gestell v065
# (True, 'Contains Stop Word: rahmen')
# fuehrungsscheibe 75.0.0956 stl.
# (True, 'Contains compound partial word: scheibe for Token: fuehrungsscheibe ')
# 32x5rx3,5 (maschienens)
# (True, 'Contains compound partial word: schi for Token: maschienens ')
# buchse  95,0 / 196,0 x 100,0 stuetzweite
# (True, 'Contains Dictionary Word: buchse')
# cz112839 for 3032376-100
# (True, 'Contains Stop Word: for')
# eis2-240h15  single motor
# (True, 'Contains Dictionary Word: eis')
# 20-20 vhm i-smart schlicht
# (True, 'Contains Dictionary Word: schlicht')
# ih04c-71/35-r901604103 liste1 *alu
# (True, 'Contains Stop Word: liste')
# zl 11/2", pn40, 1.4408/ptfe, 2-teilig
# (True, 'Contains compound partial word: eilig for Token: teilig ')
# vorstufe unlackiert fuer r917016807
# (True, 'Contains Stop Word: vorstufe')
# cz112787 for 3050717
# (True, 'Contains Stop Word: for')
# vorstufe unlackiert fuer r917016815
# (True, 'Contains Stop Word: vorstufe')
# abmaxin special_oil tank unit.
# (True, 'Contains compound partial word: maxi for Token: abmaxin ')
# vorstufe unlackiert fuer r917016866
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016825
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016828
# (True, 'Contains Stop Word: vorstufe')
# mcr3 drum brake back plate rh 203x60
# (False, '')
# sb23-ehs scheibe (iam)
# (True, 'Contains Stop Word: scheibe')
# vorstufe unlackiert fuer r917016805
# (True, 'Contains Stop Word: vorstufe')
# 716963 f00 frame 30671-000-055-20-011
# (False, '')
# fuehrungsscheibe  r902775021
# (True, 'Contains compound partial word: scheibe for Token: fuehrungsscheibe ')
# ta1908 w62-kit for pe2/h
# (True, 'Contains Stop Word: for')
# mcr3 seal kit f/c0v/2s/f* s33
# (False, '')
# 25x25rx3,5 (mittelflansch)
# (True, 'Contains compound partial word: mittel for Token: mittelflansch ')
# hd-zpfp-001401-a-1/ k1 niederdruckleit.
# (True, 'Contains compound partial word: nied for Token: niederdruckleit ')
# vorstufe unlackiert fuer r917016818
# (True, 'Contains Stop Word: vorstufe')
# abpls-jednoosý připojovací blok s akumul
# (False, '')
# vorstufe unlackiert fuer r917016829
# (True, 'Contains Stop Word: vorstufe')
# /60 no '007801' *ew* '007801' *ew*
# (False, '')
# vorstufe unlackiert fuer r917016827
# (True, 'Contains Stop Word: vorstufe')
# novelis-e-kasten poussoir
# (True, 'Contains compound partial word: novel for Token: novelis ')
# fuehrungsscheibe 75.0.0953 stl.
# (True, 'Contains compound partial word: scheibe for Token: fuehrungsscheibe ')
# vorstufe unlackiert fuer r917016816
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016865
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016826
# (True, 'Contains Stop Word: vorstufe')
# vorstufe unlackiert fuer r917016830
# (True, 'Contains Stop Word: vorstufe')
# cz112840 for 3032376-200
# (True, 'Contains Stop Word: for')
# stempel 75.0.0954 stl.
# (True, 'Contains Stop Word: stempel')
# vorstufe unlackiert fuer r917016809
# (True, 'Contains Stop Word: vorstufe')
# sealing cover w2b-0-0-15.5-o-o
# (False, '')
# abapg-motor-pumpengruppe fuer ct20
# (True, 'Contains compound partial word: pumpe for Token: pumpengruppe ')
# fuehrungsscheibe r902775018
# (True, 'Contains compound partial word: scheibe for Token: fuehrungsscheibe ')
# vorstufe unlackiert fuer r917016868
# (True, 'Contains Stop Word: vorstufe')
# mag verin retourneur tensionneur-8408415
# (True, 'Contains Stop Word: verin')
# 25-20 vhm i-smart schrupp
# (True, 'Contains compound partial word: rupp for Token: schrupp ')
# sb24-ehs scheibe (iam)
# (True, 'Contains Stop Word: scheibe')
# mcr3 drum brake s/a c0l so575 s33
# (False, '')
# novelis-e-kasten sortie
# (True, 'Contains compound partial word: novel for Token: novelis ')
# vorstufe unlackiert fuer r917016814
# (True, 'Contains Stop Word: vorstufe')
# dn4"- 2"bsp-cetop-w/oring
# (True, 'Contains compound partial word: ring for Token: oring ')
# stempel 75.0.0954
# (True, 'Contains Stop Word: stempel')
# vorstufe unlackiert fuer r917016822
# (True, 'Contains Stop Word: vorstufe')
# oelwanne 2186x 800x 220-es/tisch    v065
# (True, 'Contains Stop Word: oelwanne')
# proportional switch power pmp
# (False, '')
# msk070c motor gearbox assembly
# (False, '')
# ih04d 11/10-r901602227 liste1 *alu
# (True, 'Contains Stop Word: liste')
# mcr3 drum brake back plate lh 203x60
# (False, '')
# 0398x0494x0060/0384 s4--a teil1  d900904
# (True, 'Contains Stop Word: teil')
# grund,ng6
# (True, 'Contains Dictionary Word: grund')
# vorstufe unlackiert fuer r917016833
# (True, 'Contains Stop Word: vorstufe')
# anpl,seitl.anschl,o.lb,nd-v 1,8
# (True, 'Contains Stop Word: seitl')
# novelis-e-kasten entree
# (True, 'Contains compound partial word: novel for Token: novelis ')
# montagehuelse r909877382
# (True, 'Contains Stop Word: montagehuelse')
